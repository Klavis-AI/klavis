# %% [markdown]
# # Klavis Sandbox
#
# This notebook demonstrates how to run Klavis Sandbox environment and MCP Servers (remote + local) against a complicated task

# %%
# %pip install -q klavis python-dotenv langchain langchain-mcp-adapters langchain-anthropic
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import os
from dotenv import load_dotenv
from langchain_anthropic import ChatAnthropic
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain.agents import create_agent
from klavis import Klavis, SandboxMcpServer

load_dotenv()

CURRENT_DIR = os.path.dirname(os.path.abspath("__file__")) if os.path.dirname(os.path.abspath("__file__")) else os.getcwd()
LOCAL_MCP_SERVERS_PATH = os.path.abspath(os.path.join(CURRENT_DIR, "..", "..", "mcp_servers", "local"))

klavis_client = Klavis(api_key=os.getenv("KLAVIS_API_KEY"))

print(f"Current Directory: {CURRENT_DIR}")
print(f"MCP Servers Local Path: {LOCAL_MCP_SERVERS_PATH}")
# Out:
# Current Directory: /Users/zihaolin/src/klavis/examples/klavis-sandbox
# MCP Servers Local Path: /Users/zihaolin/src/klavis/mcp_servers/local

# %% [markdown]
# ### Step 1: Create Sandboxes environment for Gmail and Snowflake

# %%
# Create Gmail sandbox
gmail_sandbox = klavis_client.sandbox.create_sandbox(
    server_name=SandboxMcpServer.GMAIL,
)

snowflake_sandbox = klavis_client.sandbox.create_sandbox(
    server_name=SandboxMcpServer.SNOWFLAKE,
)

print(f"Gmail Sandbox: {gmail_sandbox}")
print(f"Snowflake Sandbox: {snowflake_sandbox}")
# Out:
# Gmail Sandbox: sandbox_id='1081a9e9-4615-4b64-b9f9-05b756bde058' server_url='https://gmail-mcp-server.klavis.ai/mcp/?instance_id=f8804691-def2-44a2-b5f1-d8ab033e20f0' server_name=<SandboxMcpServer.GMAIL: 'gmail'> status=<SandboxStatus.OCCUPIED: 'occupied'> message='Sandbox acquired successfully. Use the server_url to connect to the MCP server.'
# Snowflake Sandbox: sandbox_id='b4444fdf-2f9c-44b5-89ca-eab8d05424e2' server_url='https://strata.klavis.ai/mcp/?instance_id=4bc26526-2bf9-434c-b595-8bb4e9a68709' server_name=<SandboxMcpServer.SNOWFLAKE: 'snowflake'> status=<SandboxStatus.OCCUPIED: 'occupied'> message='Sandbox acquired successfully. Use the server_url to connect to the MCP server.'

# %%
# check existing environment in gmail sandbox
response = klavis_client.sandbox.dump_gmail_sandbox(
    sandbox_id=gmail_sandbox.sandbox_id,
)

print(response.data)
# Out:
# messages=[] drafts=[]

# %%
# check existing environment in snowflake sandbox
response = klavis_client.sandbox.dump_snowflake_sandbox(
    sandbox_id=snowflake_sandbox.sandbox_id,
)

print(json.dumps(response.data, indent=2))
# Out:
# {}

# %% [markdown]
# ### Step 2: Initialize Snowflake Sandbox with Data

# %%
snowflake_json_path = os.path.join(CURRENT_DIR, "snowflake.json")

with open(snowflake_json_path, "r") as f:
    snowflake_data = json.load(f)
    
klavis_client.sandbox.initialize_snowflake_sandbox(
    sandbox_id=snowflake_sandbox.sandbox_id,
    databases=snowflake_data["databases"],
)
# Out:
# InitializeSandboxResponse(sandbox_id='b4444fdf-2f9c-44b5-89ca-eab8d05424e2', status=<SandboxStatus.OCCUPIED: 'occupied'>, message='Created 8 total records across all object types', records_created={'databases': 1, 'schemas': 1, 'tables': 2, 'rows': 4})

# %%
# after loading data, check environment in snowflake sandbox
response = klavis_client.sandbox.dump_snowflake_sandbox(
    sandbox_id=snowflake_sandbox.sandbox_id,
)

print(json.dumps(response.data, indent=2))
# Out:
# {
#   "databases": [
#     {
#       "name": "SLA_MONITOR",
#       "comment": "SLA monitoring and customer support ticket tracking system",
#       "schemas": [
#         {
#           "name": "CORE",
#           "tables": [
#             {
#               "name": "TICKETS",
#               "columns": [
#                 {
#                   "name": "ID",
#                   "data_type": "NUMBER(38,0)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "USER_ID",
#                   "data_type": "NUMBER(38,0)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "TITLE",
#                   "data_type": "VARCHAR(500)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "DESCRIPTION",
#                   "data_type": "VARCHAR(16777216)",
#                   "nullable": true
#                 },
#                 {
#                   "name": "STATUS",
#                   "data_type": "VARCHAR(50)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "PRIORITY",
#                   "data_type": "VARCHAR(50)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "CREATED_AT",
#                   "data_type": "TIMESTAMP_NTZ(9)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "FIRST_RESPONSE_AT",
#                   "data_type": "TIMESTAMP_NTZ(9)",
#                   "nullable": true
#                 },
#                 {
#                   "name": "RESOLVED_AT",
#                   "data_type": "TIMESTAMP_NTZ(9)",
#                   "nullable": true
#                 }
#               ],
#               "rows": [
#                 {
#                   "values": {
#                     "ID": 101,
#                     "USER_ID": 1,
#                     "TITLE": "Cannot access dashboard",
#                     "DESCRIPTION": "Getting 404 error when trying to access main dashboard",
#                     "STATUS": "Open",
#                     "PRIORITY": "High",
#                     "CREATED_AT": "2025-12-05T10:00:00",
#                     "FIRST_RESPONSE_AT": null,
#                     "RESOLVED_AT": null
#                   }
#                 },
#                 {
#                   "values": {
#                     "ID": 102,
#                     "USER_ID": 2,
#                     "TITLE": "Payment processing failed",
#                     "DESCRIPTION": "Transaction timeout during checkout process",
#                     "STATUS": "Open",
#                     "PRIORITY": "Critical",
#                     "CREATED_AT": "2025-12-09T00:00:00",
#                     "FIRST_RESPONSE_AT": "2025-12-09T08:00:00",
#                     "RESOLVED_AT": null
#                   }
#                 }
#               ]
#             },
#             {
#               "name": "USERS",
#               "columns": [
#                 {
#                   "name": "ID",
#                   "data_type": "NUMBER(38,0)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "NAME",
#                   "data_type": "VARCHAR(255)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "EMAIL",
#                   "data_type": "VARCHAR(255)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "SERVICE_LEVEL",
#                   "data_type": "VARCHAR(50)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "CUSTOMER_MANAGER",
#                   "data_type": "VARCHAR(255)",
#                   "nullable": false
#                 },
#                 {
#                   "name": "CREATED_AT",
#                   "data_type": "TIMESTAMP_NTZ(9)",
#                   "nullable": true,
#                   "default": "CURRENT_TIMESTAMP()"
#                 },
#                 {
#                   "name": "UPDATED_AT",
#                   "data_type": "TIMESTAMP_NTZ(9)",
#                   "nullable": true,
#                   "default": "CURRENT_TIMESTAMP()"
#                 }
#               ],
#               "rows": [
#                 {
#                   "values": {
#                     "ID": 1,
#                     "NAME": "Zihao Lin",
#                     "EMAIL": "zihaolin@klavis.ai",
#                     "SERVICE_LEVEL": "Basic",
#                     "CUSTOMER_MANAGER": "zihao@klavisai.com",
#                     "CREATED_AT": "2025-12-01T00:00:00",
#                     "UPDATED_AT": "2025-12-09T14:41:24.405000"
#                   }
#                 },
#                 {
#                   "values": {
#                     "ID": 2,
#                     "NAME": "Xiangkai Zeng",
#                     "EMAIL": "xiangkaiz@klavis.ai",
#                     "SERVICE_LEVEL": "Pro",
#                     "CUSTOMER_MANAGER": "xiangkai@klavisai.com",
#                     "CREATED_AT": "2025-12-01T00:00:00",
#                     "UPDATED_AT": "2025-12-09T14:41:25.529000"
#                   }
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### Step 3: Setup MCP Client, AI Agent and kick off task

# %%
# Create MCP client with remote and local MCP Servers
mcp_client = MultiServerMCPClient({
    "snowflake": {
        "transport": "streamable_http",
        "url": snowflake_sandbox.server_url,
    },
    "gmail": {
        "transport": "streamable_http",
        "url": gmail_sandbox.server_url,
    },
    "filesystem": {
        "transport": "stdio",
        "command": "npx",
        "args": [
            "-y",
            os.path.join(LOCAL_MCP_SERVERS_PATH, "filesystem"),
            CURRENT_DIR
        ],
        "env": dict(os.environ)
    },
    "pdf-tools": {
        "transport": "stdio",
        "command": "uvx",
        "args": [
            "--from",
            os.path.join(LOCAL_MCP_SERVERS_PATH, "pdf-tools"),
            "pdf-tools-mcp",
            "--workspace_path",
            CURRENT_DIR,
            "--tempfile_dir",
            CURRENT_DIR
        ],
        "env": dict(os.environ)
    },
})

tools = await mcp_client.get_tools()
llm = ChatAnthropic(model="claude-sonnet-4-5-20250929")

agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt=(
        "You are an intelligent SLA Monitoring Agent. Your goal is to ensure compliance with Service Level Agreements (SLAs) and manage communications for breaches.\n"
        "You have access to below tools:\n"
        "1. Snowflake: To fetch user and ticket data.\n"
        "2. PDF/Filesystem: To read SLA manuals and email templates from files of the local filesystem.\n"
        "3. Gmail: to send emails if needed.\n\n"
    ),
)

# %%
# print tools
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool.name}")
# Out:
# 1. snowflake_list_databases
# 2. snowflake_create_database
# 3. snowflake_drop_database
# 4. snowflake_describe_database
# 5. snowflake_list_schemas
# 6. snowflake_create_schema
# 7. snowflake_drop_schema
# 8. snowflake_describe_schema
# 9. snowflake_list_tables
# 10. snowflake_describe_table
# 11. snowflake_preview_table
# 12. snowflake_get_table_row_count
# 13. snowflake_drop_table
# 14. snowflake_list_warehouses
# 15. snowflake_describe_warehouse
# 16. snowflake_create_warehouse
# 17. snowflake_drop_warehouse
# 18. snowflake_alter_warehouse
# 19. snowflake_execute_read_query
# 20. snowflake_execute_write_query
# 21. snowflake_get_account_info
# 22. snowflake_list_users
# 23. snowflake_list_roles
# 24. snowflake_describe_user
# 25. snowflake_describe_role
# 26. snowflake_list_grants_to_role
# 27. snowflake_get_current_account
# 28. snowflake_get_query_history
# 29. gmail_send_email
# 30. gmail_draft_email
# 31. gmail_read_email
# 32. gmail_search_emails
# 33. gmail_modify_email
# 34. gmail_delete_email
# 35. gmail_batch_modify_emails
# 36. gmail_batch_delete_emails
# 37. gmail_get_email_attachments
# 38. gmail_search_contacts
# 39. filesystem_read_file
# 40. filesystem_read_text_file
# 41. filesystem_read_media_file
# 42. filesystem_read_multiple_files
# 43. filesystem_write_file
# 44. filesystem_edit_file
# 45. filesystem_create_directory
# 46. filesystem_list_directory
# 47. filesystem_list_directory_with_sizes
# 48. filesystem_directory_tree
# 49. filesystem_move_file
# 50. filesystem_search_files
# 51. filesystem_get_file_info
# 52. filesystem_list_allowed_directories
# 53. read_pdf
# 54. get_pdf_info
# 55. extract_pages
# 56. merge_pdfs
# 57. split_pdf

# %%
user_message = (
    "Identify the tickets in the database that have exceeded the initial response time according to the relevant documentation, and send "
    "reminder emails, based on the templates mentioned in the manual, to the respective responsible managers, as well as apology emails to all involved users."
)

print("🚀 Starting agent...\n")

try:
    async for event in agent.astream_events(
        {"messages": [{"role": "user", "content": user_message}]},
        version="v2",
    ):
        kind = event["event"]
        
        if kind == "on_chat_model_stream":
            chunk = event["data"]["chunk"]
            # Try to extract content from the chunk
            if hasattr(chunk, "content"):
                content = chunk.content
                if content:
                    # Handle both string and list content
                    if isinstance(content, list):
                        for item in content:
                            if isinstance(item, dict) and "text" in item:
                                print(item["text"], end="", flush=True)
                            elif hasattr(item, "text"):
                                print(item.text, end="", flush=True)
                    elif isinstance(content, str):
                        print(content, end="", flush=True)
        
        elif kind == "on_tool_start":
            tool_name = event["name"]
            tool_input = {k: v for k, v in event["data"].get("input", {}).items() 
                          if k not in ["runtime", "config", "stream_writer", "tool_call_id", "store"]}
            print(f"\n\n🔧 {tool_name}")
            if tool_input:
                # Pretty print the input, truncate if too long
                input_str = str(tool_input)
                if len(input_str) > 200:
                    input_str = input_str[:200] + "..."
                print(f"   → {input_str}")
        
        elif kind == "on_tool_end":
            output = event["data"].get("output")
            if output:
                # Truncate long outputs for readability
                output_str = str(output)
                if len(output_str) > 300:
                    output_str = output_str[:300] + "..."
                print(f"   ✓ {output_str}")
        
        # Capture any errors
        elif kind == "on_chain_error" or kind == "on_tool_error":
            error = event["data"].get("error", event)
            print(f"\n❌ Error: {error}")

    print("\n\n✨ Agent execution completed!")
    
except Exception as e:
    print(f"\n\n❌ Error during agent execution: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# 🚀 Starting agent...
#
# I'll help you identify tickets that have exceeded the initial response time SLA and send the appropriate reminder and apology emails. Let me start by exploring the available resources.
#
# 🔧 snowflake_list_databases
#
#
# 🔧 filesystem_list_allowed_directories
#    ✓ content=[{'type': 'text', 'text': 'Allowed directories:\n/Users/zihaolin/src/klavis/examples/klavis-sandbox', 'id': 'lc_b5a685b0-cdfe-43c5-8eb9-253b7b1949b0'}] name='filesystem_list_allowed_directories' tool_call_id='toolu_01Ji3pPqn9b22QfVc6rjXZFh' artifact={'structured_content': {'content': 'Allowe...
#    ✓ content=[{'type': 'text', 'text': '{"success":true,"data":{"results":[{"created_on":"2025-12-09T14:41:23.717000-08:00","name":"SLA_MONITOR","is_default":"N","is_current":"N","origin":"","owner":"ACCOUNTADMIN","comment":"SLA monitoring and customer support ticket tracking system","options":"","retent...
#
#
# 🔧 snowflake_list_schemas
#    → {'database': 'SLA_MONITOR'}
#
#
# 🔧 filesystem_list_directory
#    → {'path': '/Users/zihaolin/src/klavis/examples/klavis-sandbox'}
#    ✓ content=[{'type': 'text', 'text': '[FILE] .env\n[FILE] .env.example\n[DIR] .venv\n[DIR] __pycache__\n[FILE] klavis_sandbox.ipynb\n[FILE] sla_manual.pdf\n[FILE] snowflake.json', 'id': 'lc_634a070f-1289-4162-a8ea-69e0d2ee34e6'}] name='filesystem_list_directory' tool_call_id='toolu_01Ya6nxVr2yg9kX8s92i...
#    ✓ content=[{'type': 'text', 'text': '{"success":true,"data":{"results":[{"created_on":"2025-12-09T14:41:23.968000-08:00","name":"CORE","is_default":"N","is_current":"N","database_name":"SLA_MONITOR","owner":"ACCOUNTADMIN","comment":"","options":"","retention_time":"1","owner_role_type":"ROLE","classif...
#
#
# 🔧 snowflake_list_tables
#    → {'database': 'SLA_MONITOR', 'schema': 'CORE'}
#
#
# 🔧 read_pdf
#    → {'file_path': 'sla_manual.pdf'}
#    ✓ content=[{'type': 'text', 'text': '{\n  "file_path": "sla_manual.pdf",\n  "num_pages": 1,\n  "metadata": {\n    "title": "sla_manual",\n    "author": "",\n    "subject": "",\n    "creator": "",\n    "producer": "Skia/PDF m144 Google Docs Renderer",\n    "creation_date": ""\n  },\n  "pages": [\n    {...
#    ✓ content=[{'type': 'text', 'text': '{"success":true,"data":{"results":[{"created_on":"2025-12-09T14:41:25.954000-08:00","name":"TICKETS","database_name":"SLA_MONITOR","schema_name":"CORE","kind":"TABLE","comment":"","cluster_by":"","rows":2,"bytes":3584,"owner":"ACCOUNTADMIN","retention_time":"1","au...
# Now let me check the structure of the tables and get the data:
#
# 🔧 snowflake_describe_table
#    → {'database': 'SLA_MONITOR', 'schema': 'CORE', 'table': 'TICKETS'}
#
#
# 🔧 snowflake_describe_table
#    → {'database': 'SLA_MONITOR', 'schema': 'CORE', 'table': 'USERS'}
#    ✓ content=[{'type': 'text', 'text': '{"success":true,"data":{"results":[{"name":"ID","type":"NUMBER(38,0)","kind":"COLUMN","null?":"N","default":null,"primary key":"N","unique key":"N","check":null,"expression":null,"comment":null,"policy name":null,"privacy domain":null},{"name":"NAME","type":"VARCHA...
#    ✓ content=[{'type': 'text', 'text': '{"success":true,"data":{"results":[{"name":"ID","type":"NUMBER(38,0)","kind":"COLUMN","null?":"N","default":null,"primary key":"N","unique key":"N","check":null,"expression":null,"comment":null,"policy name":null,"privacy domain":null},{"name":"USER_ID","type":"NUM...
#
#
# 🔧 snowflake_execute_read_query
#    → {'database': 'SLA_MONITOR', 'schema': 'CORE', 'query': "\nSELECT \n    t.ID as TICKET_ID,\n    t.USER_ID,\n    t.TITLE,\n    t.DESCRIPTION,\n    t.STATUS,\n    t.PRIORITY,\n    t.CREATED_AT,\n    t.FI...
#    ✓ content=[{'type': 'text', 'text': '{"success":true,"data":{"results":[{"TICKET_ID":101,"USER_ID":1,"TITLE":"Cannot access dashboard","DESCRIPTION":"Getting 404 error when trying to access main dashboard","STATUS":"Open","PRIORITY":"High","CREATED_AT":"2025-12-05T10:00:00","FIRST_RESPONSE_AT":null,"U...
# Perfect! I found 1 ticket that has exceeded the SLA. Let me check if there's a manager email template in the documentation or files:
#
# 🔧 filesystem_search_files
#    → {'path': '/Users/zihaolin/src/klavis/examples/klavis-sandbox', 'pattern': '*.txt'}
#
#
# 🔧 filesystem_search_files
#    → {'path': '/Users/zihaolin/src/klavis/examples/klavis-sandbox', 'pattern': '*.md'}
#    ✓ content=[{'type': 'text', 'text': 'No matches found', 'id': 'lc_c1035bac-0f23-4661-96af-9bc76e3f7d03'}] name='filesystem_search_files' tool_call_id='toolu_01EtwR24x3Q4DkPWVhsRzS44' artifact={'structured_content': {'content': 'No matches found'}}
#    ✓ content=[{'type': 'text', 'text': 'No matches found', 'id': 'lc_637414e7-44b6-4774-8bb0-190bae2e72ac'}] name='filesystem_search_files' tool_call_id='toolu_019v6NJ8kNfeZP6tRu8HoQcc' artifact={'structured_content': {'content': 'No matches found'}}
# Now I'll send the emails. Based on the SLA manual, I need to:
# 1. Send an apology email to the customer (Zihao Lin)
# 2. Send a reminder email to the responsible manager (zihao@klavisai.com)
#
# Let me prepare and send these emails:
#
# 🔧 gmail_send_email
#    → {'to': ['zihaolin@klavis.ai'], 'subject': 'Update on Your Service Request 101', 'body': 'Dear Customer,\n\nWe sincerely apologize for not responding to your service request 101 within the promised tim...
#
#
# 🔧 gmail_send_email
#    → {'to': ['zihao@klavisai.com'], 'subject': 'URGENT: SLA Breach - Ticket 101 Requires Immediate Attention', 'body': 'Dear Manager,\n\nThis is an urgent notification regarding an SLA breach that requires...
#    ✓ content=[{'type': 'text', 'text': '{\n  "message": "Email sent successfully with ID: 19b054d1cb9d9744",\n  "messageId": "19b054d1cb9d9744"\n}', 'id': 'lc_4df21e8a-d653-43d7-9469-b61817a3552a'}] name='gmail_send_email' tool_call_id='toolu_01C9NMpFg2k8NP51K2CYMWtV'
#    ✓ content=[{'type': 'text', 'text': '{\n  "message": "Email sent successfully with ID: 19b054d1c171715d",\n  "messageId": "19b054d1c171715d"\n}', 'id': 'lc_e9e64f99-5550-41ef-9aff-1bbb522f7888'}] name='gmail_send_email' tool_call_id='toolu_011zsHJRoaD24JB6zFjfUr5X'
# Perfect! I have successfully completed the SLA monitoring task. Here's a summary of what was done:
#
# ## Summary
#
# ### SLA Breach Identified:
# - **Ticket ID:** 101
# - **Customer:** Zihao Lin (zihaolin@klavis.ai)
# - **Service Level:** Basic (72-hour first response time SLA)
# - **Issue:** Cannot access dashboard (404 error)
# - **Priority:** High
# - **Created:** December 5, 2025 at 10:00 AM
# - **Time Elapsed:** 100 hours
# - **SLA Breach:** Exceeded by 28 hours (no first response provided yet)
#
# ### Actions Taken:
#
# 1. **Apology Email Sent to Customer** (zihaolin@klavis.ai)
#    - Used the template from the SLA manual (Section 6.2.1)
#    - Ticket number: 101
#    - Committed to response within 72 hours (Second Reply Time for Basic level)
#    - Provided contact phone number for urgent matters
#
# 2. **Urgent Reminder Email Sent to Manager** (zihao@klavisai.com)
#    - Detailed ticket information and breach severity
#    - Highlighted the 28-hour SLA excess
#    - Requested immediate action
#    - Notified that customer apology has been sent
#
# Both emails were successfully delivered and the responsible parties have been notified to take appropriate action to resolve this SLA breach.
#
# ✨ Agent execution completed!

# %%
# after the task is done, check environment in gmail sandbox
response = klavis_client.sandbox.dump_gmail_sandbox(
    sandbox_id=gmail_sandbox.sandbox_id,
)

# Format the output
for i, msg in enumerate(response.data.messages, 1):
    print(f"\n{'='*80}\nMessage {i}: {msg.subject}\n{'='*80}")
    print(f"From: {msg.from_} → To: {msg.to}")
    print(f"\n{msg.body}\n")
# Out:
# ================================================================================
# Message 1: Update on Your Service Request 101
# ================================================================================
# From: janemorrist@klavisai.com → To: zihaolin@klavis.ai
#
# Dear Customer,
#
# We sincerely apologize for not responding to your service request 101 within the promised timeframe.
#
# We commit to providing an initial solution or the latest status update within 72 hours, and will continue following up until the issue is fully resolved.
#
# For urgent matters, please contact us directly:
# Phone: 400-772-1234
#
# We apologize again for any inconvenience this may have caused.
#
# Best,
# MCP Inc., Customer Support Team
#
#
# ================================================================================
# Message 2: URGENT: SLA Breach - Ticket 101 Requires Immediate Attention
# ================================================================================
# From: janemorrist@klavisai.com → To: zihao@klavisai.com
#
# Dear Manager,
#
# This is an urgent notification regarding an SLA breach that requires immediate action.
#
# **Ticket Details:**
# - Ticket ID: 101
# - Customer: Zihao Lin (zihaolin@klavis.ai)
# - Service Level: Basic
# - Title: Cannot access dashboard
# - Description: Getting 404 error when trying to access main dashboard
# - Priority: High
# - Created: 2025-12-05 10:00:00
# - Time Elapsed: 100 hours
#
# **SLA Breach:**
# - Required First Response Time: 72 hours
# - Current Status: NO RESPONSE (100 hours elapsed)
# - **SLA EXCEEDED BY: 28 hours**
#
# **Required Action:**
# Please provide an immediate response to this customer within the next few hours. An apology email has already been sent to the customer notifying them of the delay and our commitment to respond within 72 hours from now.
#
# This ticket requires your immediate attention to maintain our service standards and customer satisfaction.
#
# Best regards,
# SLA Monitoring System

# %% [markdown]
# ### Step 5: Cleanup - Delete Sandboxes

# %%
klavis_client.sandbox.delete_sandbox(
    server_name=SandboxMcpServer.GMAIL,
    sandbox_id=gmail_sandbox.sandbox_id,
)

klavis_client.sandbox.delete_sandbox(
    server_name=SandboxMcpServer.SNOWFLAKE,
    sandbox_id=snowflake_sandbox.sandbox_id,
)
# Out:
# ReleaseSandboxResponse(sandbox_id='b4444fdf-2f9c-44b5-89ca-eab8d05424e2', status=<SandboxStatus.IDLE: 'idle'>, message='Sandbox b4444fdf-2f9c-44b5-89ca-eab8d05424e2 released successfully and is now available for reuse')
